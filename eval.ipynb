# %%
import sys
import os
import pandas as pd
from sklearn.metrics import f1_score


# load submission

submission_df = pd.read_csv('Visa1.csv') # the first file in the submission zip is expected to be the submission csv


# load gold standard data
gold_df = pd.read_csv('test_label .csv') # the first file in the gold standard zip is expected to be the gold standard csv


submission_df = submission_df.sort_values("rewire_id")
gold_df = gold_df.sort_values("rewire_id")


# calculate macro F1 score for the submission relative to the gold standard data

f1 = f1_score(y_true = gold_df["label_sexist"], y_pred = submission_df["label_pred"], pos_label=None, average="macro")
    # need to set pos_label to none because of quirk in sklearn 0.17, which is the version running on CodaLab..
    # https://scikit-learn.org/0.17/modules/generated/sklearn.metrics.f1_score.html#sklearn.metrics.f1_score


print("MacroF1: {}".format(f1))
# Out:
# MacroF1: 0.7586728137452036

# %%
train = pd.read_csv('data/train_set.csv', encoding='unicode_escape')
#train_all_tasks.csv
train
# Out:
#                       rewire_id  \
# 0       sexism2022_english-7358
# 1       sexism2022_english-2367
# 2       sexism2022_english-3073
# 3      sexism2022_english-14895
# 4       sexism2022_english-4118
# ...                         ...
# 13961  sexism2022_english-14185
# 13962  sexism2022_english-18629
# 13963   sexism2022_english-3320
# 13964  sexism2022_english-13309
# 13965  sexism2022_english-12402
#
#                                                     text label_sexist  \
# 0                  Damn, this writing was pretty chaotic   not sexist
# 1      Yeah, and apparently a bunch of misogynistic v...   not sexist
# 2           How the FUCK is this woman still an MP!!!???   not sexist
# 3      Understand. Know you're right. At same time I ...   not sexist
# 4         Surprized they didn't stop and rape some women   not sexist
# ...                                                  ...          ...
# 13961  complexes like the 'nice chicks' that go after...       sexist
# ...

# %%
train = pd.read_csv('train_all_tasks.csv', encoding='unicode_escape')
#
train
# Out:
#                       rewire_id  \
# 0       sexism2022_english-7358
# 1       sexism2022_english-2367
# 2       sexism2022_english-3073
# 3      sexism2022_english-14895
# 4       sexism2022_english-4118
# ...                         ...
# 13995  sexism2022_english-14185
# 13996  sexism2022_english-18629
# 13997   sexism2022_english-3320
# 13998  sexism2022_english-13309
# 13999  sexism2022_english-12402
#
#                                                     text label_sexist  \
# 0                  Damn, this writing was pretty chaotic   not sexist
# 1      Yeah, and apparently a bunch of misogynistic v...   not sexist
# 2           How the FUCK is this woman still an MP!!!???   not sexist
# 3      Understand. Know you're right. At same time I ...   not sexist
# 4         Surprized they didn't stop and rape some women   not sexist
# ...                                                  ...          ...
# 13995  complexes like the 'nice chicks' that go after...       sexist
# ...

# %%
df = train.loc[train["label_sexist"]=='sexist']
df
# Out:
#                       rewire_id  \
# 8      sexism2022_english-10142
# 11       sexism2022_english-760
# 17      sexism2022_english-1108
# 18     sexism2022_english-10099
# 19     sexism2022_english-10014
# ...                         ...
# 13943  sexism2022_english-19317
# 13956  sexism2022_english-15667
# 13959   sexism2022_english-1400
# 13960   sexism2022_english-4515
# 13961  sexism2022_english-14185
#
#                                                     text label_sexist  \
# 8      just the inside of your wallet: cash, bank car...       sexist
# 11     They get the initial chance because they are a...       sexist
# 17                       ugly chicks A pussy is a pussy.       sexist
# 18     fuck her off with a nine mm this is what you g...       sexist
# 19     How about I talk shit to an idiot like you? Ar...       sexist
# ...                                                  ...          ...
# 13943  Another Democrat with signal eyeglasses.There ...       sexist
# ...

# %%
df1 = train.loc[train["label_sexist"]=='not sexist']
df1
# Out:
#                       rewire_id  \
# 0       sexism2022_english-7358
# 1       sexism2022_english-2367
# 2       sexism2022_english-3073
# 3      sexism2022_english-14895
# 4       sexism2022_english-4118
# ...                         ...
# 13958   sexism2022_english-9123
# 13962  sexism2022_english-18629
# 13963   sexism2022_english-3320
# 13964  sexism2022_english-13309
# 13965  sexism2022_english-12402
#
#                                                     text label_sexist  \
# 0                  Damn, this writing was pretty chaotic   not sexist
# 1      Yeah, and apparently a bunch of misogynistic v...   not sexist
# 2           How the FUCK is this woman still an MP!!!???   not sexist
# 3      Understand. Know you're right. At same time I ...   not sexist
# 4         Surprized they didn't stop and rape some women   not sexist
# ...                                                  ...          ...
# 13958                    If black girl is not pure breed   not sexist
# ...
